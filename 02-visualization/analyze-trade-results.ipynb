# %%
import lzma
import pandas as pd


# describe columns type
dtype = {
    'symbol': 'category',
    'timeframe': 'category',
    'type': 'category',
}
parse_dates = ['open_time', 'close_time']

file = lzma.open('data/trade_results.csv.xz')
trade_results = pd.read_csv(file, dtype=dtype, parse_dates=parse_dates)
trade_results.head()
# Out:
#    symbol timeframe  type               open_time  open_price  \
# 0  EURUSD        M1  SELL 2017-01-01 22:53:46.482     1.05180
# 1  GBPUSD        M1   BUY 2017-01-01 23:35:18.565     1.23550
# 2  EURCHF        M1  SELL 2017-01-01 23:51:00.126     1.07120
# 3  AUDJPY        M1  SELL 2017-01-01 23:52:14.199    84.19800
# 4  CADCHF        M1   BUY 2017-01-02 00:19:16.166     0.75982
#
#                close_time  close_price  profit_in_pips
# 0 2017-01-01 23:04:08.275      1.05250             -68
# 1 2017-01-02 08:15:01.837      1.23330            -223
# 2 2017-01-02 00:45:28.484      1.07330            -204
# 3 2017-01-02 01:25:30.174     84.49200            -294
# 4 2017-01-02 00:44:28.343      0.75765            -217
